# %% [markdown]
# <a href="https://colab.research.google.com/github/akipi-ro/open_cv/blob/main/bad%E7%B7%A8%E9%9B%86%E7%94%A8%E5%90%8D%E5%89%8D%E4%BB%98%E3%81%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#サポートパッチのインポート
from google.colab.patches import cv2_imshow

#画像のインポート

import cv2

# %%
import glob
import re
import os

# %%
#1:モジュールのインポート
import glob
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %% [markdown]
# 輝度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS) # hls票色系に変換
  h,l,s = cv2.split(hls) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(l.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()


plt.show()

# %% [markdown]
# 明度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()

  
plt.show()

# %% [markdown]
# 色相

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(h.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()
plt.show()

# %% [markdown]
# 彩度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(s.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()
plt.show()

# %% [markdown]
# 全体

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  plt.title(file_name)
  plt.figure()
