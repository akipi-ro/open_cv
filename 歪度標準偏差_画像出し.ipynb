# %% [markdown]
# <a href="https://colab.research.google.com/github/akipi-ro/open_cv/blob/main/%E6%AD%AA%E5%BA%A6%E6%A8%99%E6%BA%96%E5%81%8F%E5%B7%AE_%E7%94%BB%E5%83%8F%E5%87%BA%E3%81%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#サポートパッチのインポート
from google.colab.patches import cv2_imshow

#画像のインポート

import cv2

# %%
import glob
import re
import os

# %%
#1:モジュールのインポート
import glob
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %% [markdown]
# 輝度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS) # hls票色系に変換
  h,l,s = cv2.split(hls) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(l.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()


plt.show()

# %%
import numpy as np
import scipy.stats as sstats
import cv2


print(l)
std = np.std(l)

print(std)             # 標準偏差
# Out:
# [[ 83  82  80 ... 173 172 173]
#  [ 82  82  82 ... 179 179 178]
#  [ 80  80  82 ... 180 180 179]
#  ...
#  [194 193 190 ... 193 192 189]
#  [195 194 192 ... 191 191 189]
#  [194 193 192 ... 190 191 190]]
# 64.83716845662961

# %% [markdown]
# 明度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()

  
plt.show()

# %% [markdown]
# 色相

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(h.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()
plt.show()

# %% [markdown]
# 彩度

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hls票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(s.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()
plt.show()

# %%
import pandas as pd
import pandas as pd
from sklearn import datasets

import numpy as np
import scipy
from statistics import mean, median,variance,stdev


boston = datasets.load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
var = 'DIS'
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %% [markdown]
# 全体

# %%
file = glob.glob("*.png")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS) # hsv票色系に変換
  h,l,s = cv2.split(hls) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(l.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  plt.title(file_name)
  plt.figure()
  skew = scipy.stats.skew(l)
  print(mean(skew))
# Out:
# 0.17399011844747395
# 0.6121697642468457
# -0.4928785337612323
# 0.5943930434551866
# 0.1871149043705797
# 0.370384222918479
# -0.24551303304898303
# -0.11477027545065685
# -0.762017219207748
# 1.0129823422871922
# -0.32576103650685573
# 0.4996533316266778
# 0.6426082363849965
# 0.18386667565222062
# 0.07116729683742702
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65305 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np#悪い画像群のそれぞれの歪度
x =[0.5195533753307785,
0.4168936895333037,
0.3963053400393626,
1.0255468102369807,
-0.14700316718742634,
0.25808354660319904,
1.3753585499576624,
0.5117012936900869,
0.3267485256868237,
0.308191493114187,
2.1335343344927713,
0.8466790529604599,
0.23968511528765465,
-0.38555860046726215,
1.08584057202854]
np.std(x)
# Out:
# 0.6030781149290061

# %%
np.mean(x)
# Out:
# 0.5941039954204748

# %%
skew = scipy.stats.skew(l)
# print(skew)
skew = scipy.stats.skew(l)
print(mean(skew))

# mean(l)
# Out:
# 1.08584057202854

# %%
x =[0.3203586664329042,
0.8067612626834793,
-0.5147768336331423,
-0.0852785651129351,
-0.05442129021439027,
0.19565859844171174,
0.948442912854045,
1.1479873792565014,
0.3367728837550726,
0.23431789051487587,
0.22949025068300585,
-0.43244105717289183,
-0.04555421110856588,
-0.10547639261697023,
0.04615187604449248,
0.21777550037612411,
0.5786781054925964,
0.24823494270730348,
-0.8163172550009078,
0.15312396831562644,
0.957464272673261,
0.34902485252862453,
-0.026472767236465744,
-0.017763170043926402,
1.2571461772812738]

np.std(x)
# Out:
# 0.4921545591039593

# %%
np.mean(x)
# Out:
# 0.23715551991602812

# %%
x =[0.17399011844747395,
0.6121697642468457,
-0.4928785337612323,
0.5943930434551866,
0.1871149043705797,
0.370384222918479,
-0.24551303304898303,
-0.11477027545065685,
-0.762017219207748,
1.0129823422871922,
-0.32576103650685573,
0.4996533316266778,
0.6426082363849965,
0.18386667565222062,
0.07116729683742702]

np.std(x)
# Out:
# 0.46725638317576107

# %%
np.mean(x)
# Out:
# 0.1604926558834402
