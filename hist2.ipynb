# %% [markdown]
# <a href="https://colab.research.google.com/github/akipi-ro/open_cv/blob/main/hist2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#サポートパッチのインポート
from google.colab.patches import cv2_imshow

#画像のインポート

import cv2

# %%
import glob
import re
import os

# %%
import os
desktop_dir = os.path.expanduser('~/Desktop')
print(desktop_dir)
# Out:
# /root/Desktop

# %%
#1:モジュールのインポート
import glob
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %%
for x in  file:
  file_name = x.split("/")[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-05c2ad59b8b3> in <module>()
# ----> 1 for x in  file:
#       2   file_name = x.split("/")[-1]
#
# NameError: name 'file' is not defined

# %%
file_name[]
# Out:
#   File "<ipython-input-10-ee7c7775856f>", line 1
#     file_name[]
#               ^
# SyntaxError: invalid syntax

# %%
file = glob.glob("*.jpg")
# file[0]
file[2]
# Out:
# '81.jpg'

# %% [markdown]
# 輝度

# %%
file = glob.glob("*.png")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS) # hls票色系に変換
  h,l,s = cv2.split(hls) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(l.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()

  
plt.show()

# %% [markdown]
# 明度

# %% [markdown]
# 彩度

# %%
file = glob.glob("*.png")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS) # hls票色系に変換
  h,l,s = cv2.split(hls) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(l.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  # plt.figure()

  
plt.show()

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  plt.figure()

  
# plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':
# ...

# %%
file = glob.glob("*.jpg")

for x in  file:
  img=cv2.imread(file[x])
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
  h,s,v = cv2.split(hsv) # 各成分に分割
  
  # plt.figure()　前に置くとle6だけなぜか出る
  plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
  plt.figure()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-d69db2ceb4ca> in <module>()
#       2
#       3 for x in  file:
# ----> 4   img=cv2.imread(file[x])
#       5   hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
#       6   h,s,v = cv2.split(hsv) # 各成分に分割
#
# TypeError: list indices must be integers or slices, not str

# %%
file = glob.glob("*.jpg")
# file[1]

for x in  file:
  img=cv2.imread(file[2])
  
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F518AB53050>

# %% [markdown]
# 目盛りをすべて同じにする

# %%
# for x in  range(3):
#   plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')

#   plt.show()

# %%
plt.figure()
plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
plt.hist(v2.ravel(), 256,[0,256],alpha=0.3, histtype='stepfilled', color='r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-aceb3b5f65f4> in <module>()
#       2 plt.figure()
#       3 plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')
# ----> 4 plt.hist(v2.ravel(), 256,[0,256],alpha=0.3, histtype='stepfilled', color='r')
#       5
#       6 plt.show()
#
# NameError: name 'v2' is not defined

# %%
file_name
# Out:
# '20.jpg'

# %%
# cv2_imshow(img)

# %%
 "for x in txt_file_path:\n",
    "    player=x.split(\"/\")[2]#プレイヤーの名前を抽出\n",
    "    \n",
    "    file_name = x.split(\"/\")[-1].split(\".\")[0]\n",
    "    path_name = \"{}_change.csv\".format(file_name)\n",
    "    \n",
    "    out_root_path = \"text_to_speech/{}\".format(player)\n",
    "    if not os.path.exists(out_root_path):\n",
    "        os.mkdir(out_root_path)\n",
    "    \n",
    "    text_file = pd.read_table(x, header=None, sep=\",\")\n",
    "    df_text_file = text_file.T#縦に表示する\n",
    "    df_text_file = df_text_file.rename(columns={0:\"text\"})#テキストカラムに対して\n",
    "    df_text_file.to_csv(\"{}/{}\".format(out_root_path,path_name))\n",
    "    "
   ]

# %%
for x in txt_file_path:

# %%
for I in  file:
  img=cv2.imread(file[]) # 画像読み込み
# Out:
#   File "<ipython-input-6-b800a8ff6d0f>", line 2
#     img=cv2.imread(file[]) # 画像読み込み
#                         ^
# SyntaxError: invalid syntax

# %%
#1:モジュールのインポート
import glob
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %%
files = glob.glob("*.jpg")

for n in files:
  # for r in n:
    img = cv2.imread(r)
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    # h,s,v = cv2.split(hsv) # 各成分に分割

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f4cbd75eccfc> in <module>()
#       3 for n in files:
#       4   # for r in n:
# ----> 5     img = cv2.imread(r)
#       6     # img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       7     # h,s,v = cv2.split(hsv) # 各成分に分割
#
# NameError: name 'r' is not defined

# %%
files = glob.glob("*.jpg")

for n in range(len(files)):
    img = cv2.imread(files[n])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    h,s,v = cv2.split(hsv) # 各成分に分割

plt.imshow(img)

# %%
plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')

plt.show()

# %%
img=cv2.imread("６.jpg") # 画像読み込み
# img2=cv2.imread("3.jpg") # 画像読み込み

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
h,s,v = cv2.split(hsv) # 各成分に分割

# hsv2 = cv2.cvtColor(img2, cv2.COLOR_BGR2HSV)# hsv票色系に変換
# h2,s2,v2 = cv2.split(hsv2) # 各成分に分割

# %% [markdown]
# #8月２日

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('input.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-91f7a1a35be0> in <module>()
#       1
#       2 img = cv2.imread('input.jpg',0)
# ----> 3 plt.hist(img.ravel(),256,[0,256]); plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'ravel'

# %%
img = cv2.imread('input.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %% [markdown]
# #分割しない場合

# %%
file = glob.glob("*.jpg")

for x in  file:
  file_name = x.split("/")[-1]
  img=cv2.imread(file_name)
  
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
  # h,s,v = cv2.split(hsv) # 各成分に分割
  
  plt.figure()
  plt.hist(hsv.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')

plt.show()
