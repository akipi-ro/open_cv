# %% [markdown]
# <a href="https://colab.research.google.com/github/akipi-ro/open_cv/blob/main/hist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#サポートパッチのインポート
from google.colab.patches import cv2_imshow

#画像のインポート

import cv2

# %%
import glob
import re
import os

# %%
import os
desktop_dir = os.path.expanduser('~/Desktop')
print(desktop_dir)
# Out:
# /root/Desktop

# %%
file = glob.glob("*.jpg")
# file[0]
file
# Out:
# ['22.jpg',
#  '50.jpg',
#  '46.jpg',
#  '36.jpg',
#  '44.jpg',
#  '５.jpg',
#  '49.jpg',
#  '20.jpg',
#  '84.jpg',
#  '60.jpg',
#  '28.jpg',
#  '９.jpg',
#  '19.jpg',
#  '６.jpg',
#  '30.jpg',
#  '32.jpg']

# %%
for I in  file:
  # img2=cv2.imread()
  print(I[0:6])
  # print(file[1])
# Out:
# 22.jpg
# 50.jpg
# 46.jpg
# 36.jpg
# 44.jpg
# ５.jpg
# 49.jpg
# 20.jpg
# 84.jpg
# 60.jpg
# 28.jpg
# ９.jpg
# 19.jpg
# ６.jpg
# 30.jpg
# 32.jpg

# %%
for I in  file:
  img=cv2.imread(file[]) # 画像読み込み
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-cf7fa5272ef5> in <module>()
#       1 for I in  file:
# ----> 2   img=cv2.imread(file[I]) # 画像読み込み
#
# TypeError: list indices must be integers or slices, not str

# %%
#1:モジュールのインポート
import glob
import matplotlib.pyplot as plt
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

# %%
files = glob.glob("*.jpg")

for n in files:
  # for r in n:
    img = cv2.imread(r)
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    # h,s,v = cv2.split(hsv) # 各成分に分割

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-27bbd51e7260> in <module>()
#       7     # h,s,v = cv2.split(hsv) # 各成分に分割
#       8
# ----> 9 plt.imshow(img)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
files = glob.glob("*.jpg")

for n in range(len(files)):
    img = cv2.imread(files[n])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
    h,s,v = cv2.split(hsv) # 各成分に分割

plt.imshow(img)

# %%
plt.hist(v.ravel(), 256,[0,256], alpha=0.3, histtype='stepfilled', color='r')

plt.show()

# %%
img=cv2.imread("６.jpg") # 画像読み込み
# img2=cv2.imread("3.jpg") # 画像読み込み

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # hsv票色系に変換
h,s,v = cv2.split(hsv) # 各成分に分割

# hsv2 = cv2.cvtColor(img2, cv2.COLOR_BGR2HSV)# hsv票色系に変換
# h2,s2,v2 = cv2.split(hsv2) # 各成分に分割
